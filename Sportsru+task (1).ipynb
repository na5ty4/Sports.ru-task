# %%
import os          

os.chdir('E:\python')

# %%
import pandas as pd

d = pd.read_csv('dataset_Facebook.csv', ';')    # Supply the file name (path)

d.head(10)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
# 9            139441   Photo         3          12             6         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# ...

# %%
d.describe() #Среднее, макс, мин, медиана - 50% для всей таблицы
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
d.mode(numeric_only=True) #Мода для всей
# Out:
#     Page total likes  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 0           136393.0       1.0        10.0           7.0        3.0   0.0
# 1                NaN       NaN         NaN           NaN        NaN   NaN
# 2                NaN       NaN         NaN           NaN        NaN   NaN
# 3                NaN       NaN         NaN           NaN        NaN   NaN
# 4                NaN       NaN         NaN           NaN        NaN   NaN
# 5                NaN       NaN         NaN           NaN        NaN   NaN
# 6                NaN       NaN         NaN           NaN        NaN   NaN
# 7                NaN       NaN         NaN           NaN        NaN   NaN
# 8                NaN       NaN         NaN           NaN        NaN   NaN
# 9                NaN       NaN         NaN           NaN        NaN   NaN
# 10               NaN       NaN         NaN           NaN        NaN   NaN
# 11               NaN       NaN         NaN           NaN        NaN   NaN
# ...

# %%
d.groupby(['Type']).describe() #По типу
# Out:
#                 Category  Lifetime Engaged Users  \
# Type
# Link   count   22.000000               22.000000
#        mean     1.136364              342.818182
#        std      0.467563              340.174414
#        min      1.000000               24.000000
#        25%      1.000000              105.000000
#        50%      1.000000              244.000000
#        75%      1.000000              422.000000
#        max      3.000000             1374.000000
# Photo  count  426.000000              426.000000
#        mean     1.917840              818.946009
#        std      0.884007              868.447092
#        min      1.000000                9.000000
#        25%      1.000000              399.000000
#        50%      2.000000              605.500000
#        75%      3.000000              949.000000
#        max      3.000000            11452.000000
# Status count   45.000000               45.000000
#        mean     2.022222             2040.222222
# ...

# %%
d.groupby(['Type']).apply(lambda x: x.mode()) #Мода для каждого из типов
# Out:
#            Page total likes    Type  Category  Post Month  Post Weekday  \
# Type
# Link   0           138353.0    Link       1.0        12.0           6.0
#        1                NaN     NaN       NaN         NaN           NaN
# Photo  0           124940.0   Photo       1.0        10.0           7.0
#        1                NaN     NaN       NaN         NaN           NaN
#        2                NaN     NaN       NaN         NaN           NaN
#        3                NaN     NaN       NaN         NaN           NaN
#        4                NaN     NaN       NaN         NaN           NaN
#        5                NaN     NaN       NaN         NaN           NaN
#        6                NaN     NaN       NaN         NaN           NaN
#        7                NaN     NaN       NaN         NaN           NaN
#        8                NaN     NaN       NaN         NaN           NaN
#        9                NaN     NaN       NaN         NaN           NaN
# ...

# %%
d['Lifetime Engaged Users'].idxmax()
# Out:
# 446

# %%
d.loc[446]
# Out:
# Page total likes                                                        96749
# Type                                                                    Photo
# Category                                                                    1
# Post Month                                                                  3
# Post Weekday                                                                1
# Post Hour                                                                   2
# Paid                                                                        1
# Lifetime Post Total Reach                                               98816
# Lifetime Post Total Impressions                                        125026
# Lifetime Engaged Users                                                  11452
# Lifetime Post Consumers                                                 11328
# Lifetime Post Consumptions                                              18115
# ...
